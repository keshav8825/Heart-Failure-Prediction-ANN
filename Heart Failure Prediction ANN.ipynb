# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
# Out:
# WARNING:tensorflow:From C:\Users\91764\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# # Data Visualisation

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
cols= ["#6daa9f","#774571"]
sns.countplot(x= data["DEATH_EVENT"], palette= cols)
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
#Examaning a corelation matrix of all the features 
cmap = sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

# %%
#Evauating age distrivution 
plt.figure(figsize=(20,12))
#colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
Days_of_week=sns.countplot(x=data['age'],data=data, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
sns.kdeplot(x=data["time"], y=data["age"], hue =data["DEATH_EVENT"], palette=cols)
# Out:
# <Axes: xlabel='time', ylabel='age'>

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#looking at the scaled features
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df,palette = colours)
plt.xticks(rotation=90)
plt.show()

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=7)

# %% [markdown]
# # Model Building
# In this project, we build an artificial neural network.
#
# Following steps are involved in the model building
#
# Initialising the ANN
# Defining by adding layers
# Compiling the ANN
# Train the ANN

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from keras.optimizers import SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# WARNING:tensorflow:From C:\Users\91764\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\91764\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/500
# WARNING:tensorflow:From C:\Users\91764\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\91764\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 [==============================] - 2s 140ms/step - loss: 0.6932 - accuracy: 0.4469 - val_loss: 0.6928 - val_accuracy: 0.6667
# Epoch 2/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6927 - accuracy: 0.6480 - val_loss: 0.6920 - val_accuracy: 0.6667
# Epoch 3/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6919 - accuracy: 0.6480 - val_loss: 0.6912 - val_accuracy: 0.6667
# Epoch 4/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6913 - accuracy: 0.6480 - val_loss: 0.6904 - val_accuracy: 0.6667
# Epoch 5/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6904 - accuracy: 0.6480 - val_loss: 0.6897 - val_accuracy: 0.6667
# Epoch 6/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6899 - accuracy: 0.6480 - val_loss: 0.6889 - val_accuracy: 0.6667
# Epoch 7/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6891 - accuracy: 0.6480 - val_loss: 0.6880 - val_accuracy: 0.6667
# Epoch 8/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6883 - accuracy: 0.6480 - val_loss: 0.6872 - val_accuracy: 0.6667
# Epoch 9/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6876 - accuracy: 0.6480 - val_loss: 0.6864 - val_accuracy: 0.6667
# Epoch 10/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6869 - accuracy: 0.6480 - val_loss: 0.6854 - val_accuracy: 0.6667
# Epoch 11/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6860 - accuracy: 0.6480 - val_loss: 0.6845 - val_accuracy: 0.6667
# Epoch 12/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6850 - accuracy: 0.6480 - val_loss: 0.6834 - val_accuracy: 0.6667
# Epoch 13/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6848 - accuracy: 0.6480 - val_loss: 0.6822 - val_accuracy: 0.6667
# Epoch 14/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6831 - accuracy: 0.6480 - val_loss: 0.6810 - val_accuracy: 0.6667
# Epoch 15/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6827 - accuracy: 0.6480 - val_loss: 0.6795 - val_accuracy: 0.6667
# Epoch 16/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6805 - accuracy: 0.6480 - val_loss: 0.6778 - val_accuracy: 0.6667
# Epoch 17/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6778 - accuracy: 0.6480 - val_loss: 0.6756 - val_accuracy: 0.6667
# Epoch 18/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6769 - accuracy: 0.6480 - val_loss: 0.6730 - val_accuracy: 0.6667
# Epoch 19/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6752 - accuracy: 0.6480 - val_loss: 0.6700 - val_accuracy: 0.6667
# Epoch 20/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6699 - accuracy: 0.6480 - val_loss: 0.6665 - val_accuracy: 0.6667
# Epoch 21/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6647 - accuracy: 0.6480 - val_loss: 0.6621 - val_accuracy: 0.6667
# Epoch 22/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6621 - accuracy: 0.6480 - val_loss: 0.6568 - val_accuracy: 0.6667
# Epoch 23/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6599 - accuracy: 0.6480 - val_loss: 0.6511 - val_accuracy: 0.6667
# Epoch 24/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6498 - accuracy: 0.6480 - val_loss: 0.6445 - val_accuracy: 0.6667
# Epoch 25/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6533 - accuracy: 0.6480 - val_loss: 0.6370 - val_accuracy: 0.6667
# Epoch 26/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6400 - accuracy: 0.6480 - val_loss: 0.6286 - val_accuracy: 0.6667
# Epoch 27/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6271 - accuracy: 0.6480 - val_loss: 0.6185 - val_accuracy: 0.6667
# Epoch 28/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6327 - accuracy: 0.6425 - val_loss: 0.6081 - val_accuracy: 0.6667
# Epoch 29/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6138 - accuracy: 0.6648 - val_loss: 0.5978 - val_accuracy: 0.6667
# Epoch 30/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6024 - accuracy: 0.7095 - val_loss: 0.5862 - val_accuracy: 0.6667
# Epoch 31/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5991 - accuracy: 0.7039 - val_loss: 0.5750 - val_accuracy: 0.7111
# Epoch 32/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5944 - accuracy: 0.7151 - val_loss: 0.5646 - val_accuracy: 0.7333
# Epoch 33/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6004 - accuracy: 0.7430 - val_loss: 0.5558 - val_accuracy: 0.7556
# Epoch 34/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5774 - accuracy: 0.7207 - val_loss: 0.5462 - val_accuracy: 0.7556
# Epoch 35/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5646 - accuracy: 0.7654 - val_loss: 0.5372 - val_accuracy: 0.7556
# Epoch 36/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5519 - accuracy: 0.7654 - val_loss: 0.5270 - val_accuracy: 0.8000
# Epoch 37/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5657 - accuracy: 0.7765 - val_loss: 0.5173 - val_accuracy: 0.8000
# Epoch 38/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5606 - accuracy: 0.7821 - val_loss: 0.5081 - val_accuracy: 0.8222
# Epoch 39/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5377 - accuracy: 0.7821 - val_loss: 0.5002 - val_accuracy: 0.8222
# Epoch 40/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5073 - accuracy: 0.8212 - val_loss: 0.4936 - val_accuracy: 0.8222
# Epoch 41/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4929 - accuracy: 0.8268 - val_loss: 0.4858 - val_accuracy: 0.8222
# Epoch 42/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5151 - accuracy: 0.7989 - val_loss: 0.4787 - val_accuracy: 0.8222
# Epoch 43/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5162 - accuracy: 0.8324 - val_loss: 0.4730 - val_accuracy: 0.8222
# Epoch 44/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5381 - accuracy: 0.7542 - val_loss: 0.4705 - val_accuracy: 0.8222
# Epoch 45/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5340 - accuracy: 0.7821 - val_loss: 0.4681 - val_accuracy: 0.8444
# Epoch 46/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4982 - accuracy: 0.8212 - val_loss: 0.4659 - val_accuracy: 0.8444
# Epoch 47/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5518 - accuracy: 0.7486 - val_loss: 0.4646 - val_accuracy: 0.8444
# Epoch 48/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4646 - accuracy: 0.8101 - val_loss: 0.4618 - val_accuracy: 0.8444
# Epoch 49/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5483 - accuracy: 0.7598 - val_loss: 0.4597 - val_accuracy: 0.8444
# Epoch 50/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5121 - accuracy: 0.7933 - val_loss: 0.4579 - val_accuracy: 0.8444
# Epoch 51/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5104 - accuracy: 0.7877 - val_loss: 0.4553 - val_accuracy: 0.8444
# Epoch 52/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5191 - accuracy: 0.7933 - val_loss: 0.4540 - val_accuracy: 0.8444
# Epoch 53/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5425 - accuracy: 0.7933 - val_loss: 0.4539 - val_accuracy: 0.8444
# Epoch 54/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5261 - accuracy: 0.7598 - val_loss: 0.4532 - val_accuracy: 0.8444
# Epoch 55/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4838 - accuracy: 0.8212 - val_loss: 0.4521 - val_accuracy: 0.8444
# Epoch 56/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4881 - accuracy: 0.8101 - val_loss: 0.4511 - val_accuracy: 0.8444
# Epoch 57/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4565 - accuracy: 0.8324 - val_loss: 0.4496 - val_accuracy: 0.8444
# Epoch 58/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5086 - accuracy: 0.7933 - val_loss: 0.4493 - val_accuracy: 0.8444
# Epoch 59/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5245 - accuracy: 0.7709 - val_loss: 0.4501 - val_accuracy: 0.8444
# Epoch 60/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5091 - accuracy: 0.7598 - val_loss: 0.4514 - val_accuracy: 0.8444
# Epoch 61/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4547 - accuracy: 0.8380 - val_loss: 0.4510 - val_accuracy: 0.8444
# Epoch 62/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5124 - accuracy: 0.7933 - val_loss: 0.4516 - val_accuracy: 0.8444
# Epoch 63/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5259 - accuracy: 0.8156 - val_loss: 0.4520 - val_accuracy: 0.8222
# Epoch 64/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5062 - accuracy: 0.8156 - val_loss: 0.4516 - val_accuracy: 0.8222
# Epoch 65/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4894 - accuracy: 0.7989 - val_loss: 0.4506 - val_accuracy: 0.8222
# Epoch 66/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4841 - accuracy: 0.8324 - val_loss: 0.4496 - val_accuracy: 0.8222
# Epoch 67/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5192 - accuracy: 0.7821 - val_loss: 0.4494 - val_accuracy: 0.8222
# Epoch 68/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4911 - accuracy: 0.8101 - val_loss: 0.4489 - val_accuracy: 0.8222
# Epoch 69/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4892 - accuracy: 0.8156 - val_loss: 0.4475 - val_accuracy: 0.8222
# Epoch 70/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4555 - accuracy: 0.7989 - val_loss: 0.4462 - val_accuracy: 0.8222
# Epoch 71/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4695 - accuracy: 0.8212 - val_loss: 0.4455 - val_accuracy: 0.8222
# Epoch 72/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4991 - accuracy: 0.8101 - val_loss: 0.4455 - val_accuracy: 0.8222
# Epoch 73/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4869 - accuracy: 0.7933 - val_loss: 0.4459 - val_accuracy: 0.8222
# Epoch 74/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4633 - accuracy: 0.8156 - val_loss: 0.4451 - val_accuracy: 0.8222
# Epoch 75/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4888 - accuracy: 0.8101 - val_loss: 0.4443 - val_accuracy: 0.8222
# Epoch 76/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4827 - accuracy: 0.8324 - val_loss: 0.4426 - val_accuracy: 0.8222
# Epoch 77/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5080 - accuracy: 0.7821 - val_loss: 0.4416 - val_accuracy: 0.8222
# Epoch 78/500
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4928 - accuracy: 0.8045 - val_loss: 0.4416 - val_accuracy: 0.8222
# Epoch 79/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5001 - accuracy: 0.7877 - val_loss: 0.4415 - val_accuracy: 0.8222
# Epoch 80/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4771 - accuracy: 0.8324 - val_loss: 0.4416 - val_accuracy: 0.8222
# Epoch 81/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5105 - accuracy: 0.8212 - val_loss: 0.4421 - val_accuracy: 0.8222
# Epoch 82/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4582 - accuracy: 0.7933 - val_loss: 0.4421 - val_accuracy: 0.8222
# Epoch 83/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4767 - accuracy: 0.7821 - val_loss: 0.4423 - val_accuracy: 0.8222
# Epoch 84/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4981 - accuracy: 0.8045 - val_loss: 0.4423 - val_accuracy: 0.8222
# Epoch 85/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4661 - accuracy: 0.8212 - val_loss: 0.4425 - val_accuracy: 0.8222
# Epoch 86/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4944 - accuracy: 0.7654 - val_loss: 0.4438 - val_accuracy: 0.8222
# Epoch 87/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4642 - accuracy: 0.7709 - val_loss: 0.4464 - val_accuracy: 0.8000
# Epoch 88/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4405 - accuracy: 0.8268 - val_loss: 0.4487 - val_accuracy: 0.8000
# Epoch 89/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4203 - accuracy: 0.8156 - val_loss: 0.4503 - val_accuracy: 0.8000
# Epoch 90/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4673 - accuracy: 0.7989 - val_loss: 0.4501 - val_accuracy: 0.8000
# Epoch 91/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4406 - accuracy: 0.7709 - val_loss: 0.4497 - val_accuracy: 0.8222
# Epoch 92/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4588 - accuracy: 0.7989 - val_loss: 0.4491 - val_accuracy: 0.8000
# Epoch 93/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4678 - accuracy: 0.8324 - val_loss: 0.4471 - val_accuracy: 0.8222
# Epoch 94/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4355 - accuracy: 0.8324 - val_loss: 0.4469 - val_accuracy: 0.8000
# Epoch 95/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4251 - accuracy: 0.8268 - val_loss: 0.4477 - val_accuracy: 0.8000
# Epoch 96/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4174 - accuracy: 0.8212 - val_loss: 0.4474 - val_accuracy: 0.8222
# Epoch 97/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4054 - accuracy: 0.8547 - val_loss: 0.4473 - val_accuracy: 0.8000
# Epoch 98/500
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4473 - accuracy: 0.8212 - val_loss: 0.4477 - val_accuracy: 0.8000

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 77.21%

# %% [markdown]
# # Plotting training and validation loss over epochs

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# # Plotting training and validation accuracy over epochs

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # CONCLUSIONS

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        57
#            1       0.56      0.56      0.56        18
#
#     accuracy                           0.79        75
#    macro avg       0.71      0.71      0.71        75
# weighted avg       0.79      0.79      0.79        75
